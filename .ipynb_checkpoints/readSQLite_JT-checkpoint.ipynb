# %%
import sqlite3
from sqlite3 import Error
import sqlalchemy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import bq_helper
from bq_helper import BigQueryHelper
usfs = BigQueryHelper(active_project="bigquery-public-data",
                                   dataset_name="usfs_fia")
from matplotlib import dates
import seaborn as sns

# %%
#function for creating the dates for the x-axis for regression plots
@plt.FuncFormatter
def fake_dates(x, pos):
    """ Custom formater to turn floats into e.g., 2016-05-08"""
    return dates.num2date(x).strftime('%Y-%m-%d')

# %%
usfs.list_tables()
# Out:
# ['condition',
#  'estimated_forestland_acres',
#  'estimated_timberland_acres',
#  'plot',
#  'plot_tree',
#  'population',
#  'population_estimation_unit',
#  'population_evaluation',
#  'population_evaluation_group',
#  'population_evaluation_type',
#  'population_stratum',
#  'population_stratum_assign',
#  'tree']

# %% [markdown]
# See what's in plot_tree

# %%
usfs.table_schema('tree')
# Out:
#                                name     type      mode  \
# 0              tree_sequence_number  INTEGER  NULLABLE
# 1              plot_sequence_number  INTEGER  NULLABLE
# 2     previous_tree_sequence_number  INTEGER  NULLABLE
# 3               tree_inventory_year  INTEGER  NULLABLE
# 4                   tree_state_code  INTEGER  NULLABLE
# ..                              ...      ...       ...
# 250                  inc5yrht_pnwrs   STRING  NULLABLE
# 251                    inc5yr_pnwrs   STRING  NULLABLE
# 252  ring_count_inner_2inches_pnwrs   STRING  NULLABLE
# 253                ring_count_pnwrs   STRING  NULLABLE
# 254             snag_dis_code_pnwrs   STRING  NULLABLE
#
#                                            description
# 0    Foreign key linking the tree regional biomass ...
# 1    Foreign key linking the subplot record to the ...
# 2    Foreign key linking the tree to the previous i...
# 3    The year that best represents when the invento...
# 4    Bureau of the Census Federal Information Proce...
# ..                                                 ...
# 250
# 251
# 252
# 253
# 254
#
# [255 rows x 4 columns]

# %% [markdown]
# From the description, find the code of the tree (is it unique?)

# %%
usfs.table_schema('tree')[usfs.table_schema('tree')["description"] == "An identifier for a plot. Along with state code, inventory year, tree survey unit code, County code and/or some other combinations of variables, PLOT may be used to uniquely identify a plot."].index.tolist()
# Out:
# [7]

# %%
usfs.table_schema('tree').loc[usfs.table_schema('tree').type=="STRING"].head(45)
# Out:
#                                                   name    type      mode  \
# 15                               tree_status_code_name  STRING  NULLABLE
# 17                                 species_common_name  STRING  NULLABLE
# 18                             species_scientific_name  STRING  NULLABLE
# 20                             species_group_code_name  STRING  NULLABLE
# 23                           diameter_height_code_name  STRING  NULLABLE
# 26                             height_method_code_name  STRING  NULLABLE
# 29                                tree_class_code_name  STRING  NULLABLE
# 32                               crown_class_code_name  STRING  NULLABLE
# 35                         cause_death_agent_code_name  STRING  NULLABLE
# 38                              damage_location_1_name  STRING  NULLABLE
# 40                                  damage_type_1_name  STRING  NULLABLE
# 42                              damage_severity_1_name  STRING  NULLABLE
# 44                              damage_location_2_name  STRING  NULLABLE
# 46                                  damage_type_2_name  STRING  NULLABLE
# 48                              damage_severity_2_name  STRING  NULLABLE
# 50                               decay_class_code_name  STRING  NULLABLE
# 70                            diameter_check_code_name  STRING  NULLABLE
# 73                             salvable_dead_code_name  STRING  NULLABLE
# 76                            crown_position_code_name  STRING  NULLABLE
# 78                      crown_light_exposure_code_name  STRING  NULLABLE
# 80                       crown_vigor_code_sapling_name  STRING  NULLABLE
# 82                             crown_density_code_name  STRING  NULLABLE
# 84                             crown_dieback_code_name  STRING  NULLABLE
# 86                      foliage_transparency_code_name  STRING  NULLABLE
# 101                                    form_class_name  STRING  NULLABLE
# 112                                mortality_code_name  STRING  NULLABLE
# 116                          mistletoe_class_code_name  STRING  NULLABLE
# 119                                reconcile_code_name  STRING  NULLABLE
# 130      periodic_annual_growth_removal_mortality_flag  STRING  NULLABLE
# 132  tree_class_code_northeastern_research_station_...  STRING  NULLABLE
# 134     tree_class_code_southern_research_station_name  STRING  NULLABLE
# 136  tree_class_code_north_central_research_station...  STRING  NULLABLE
# 138  tree_class_code_rocky_mountain_research_statio...  STRING  NULLABLE
# 140                            standing_dead_code_name  STRING  NULLABLE
# 142                     previous_tree_status_code_name  STRING  NULLABLE
# 143                       previous_woodland_stem_count  STRING  NULLABLE
# 159  tree_bored_code_pacific_northwest_research_sta...  STRING  NULLABLE
# 161  damage_location_1_pacific_northwest_research_s...  STRING  NULLABLE
# 163  damage_location_2_pacific_northwest_research_s...  STRING  NULLABLE
# 165  diameter_check_pacific_northwest_research_stat...  STRING  NULLABLE
# 170  leafy_mistletoe_class_code_pacific_northwest_r...  STRING  NULLABLE
# 174  damage_severity_1_b_pacific_northwest_research...  STRING  NULLABLE
# 177  damage_severity_2_b_pacific_northwest_research...  STRING  NULLABLE
# 180  unknown_damage_type_1_pacific_northwest_resear...  STRING  NULLABLE
# 182  unknown_damage_type_2_pacific_northwest_resear...  STRING  NULLABLE
#
#                                            description
# 15   A code indicating whether the sample tree is l...
# 17   An FIA tree species code. Refer to appendix F ...
# 18   An FIA tree species code. Refer to appendix F ...
# 20   A code assigned to each tree species in order ...
# 23   A code indicating the location at which diamet...
# 26   A code indicating how length (height) was dete...
# 29   A code indicating the general quality of the t...
# 32   A code indicating the amount of sunlight recei...
# 35   When PLOT.MANUAL 1.0, this variable was collec...
# 38   A code indicating where damage (meeting or exc...
# 40   A code indicating the kind of damage (meeting ...
# 42   A code indicating how much of the tree is affe...
# 44   A code indicating where secondary damage (meet...
# 46   A code indicating the kind of secondary damage...
# 48   A code indicating how much of the tree is affe...
# 50   A code indicating the stage of decay that pred...
# 70   A code indicating the reliability of the diame...
# 73   A standing or down dead tree considered mercha...
# 76   The relative position of each tree in relation...
# 78   A code indicating the amount of light being re...
# 80   A code indicating the vigor of sapling crowns....
# 82   A code indicating how dense the tree crown is,...
# 84   A code indicating the amount of recent dead ma...
# 86   A code indicating the amount of light penetrat...
# 101  A code used in calculating merchantable bole n...
# 112  Used for a tree that was alive within past 5 y...
# 116  A rating of dwarf mistletoe infection. Recorde...
# 119  Recorded for remeasurement locations only. A c...
# 130  A code indicating if this subplot is part of a...
# 132  In annual inventory, this code represents a cl...
# 134  A code indicating the general quality of the t...
# 136  In annual inventory, a code indicating tree su...
# 138  A code indicating the general quality of the t...
# 140  A code indicating if a tree qualifies as stand...
# 142  Tree status that was recorded at the previous ...
# 143  Woodland tree species stem count that was reco...
# 159  Used in conjunction with tree age (BHAGE and T...
# 161  The location on the tree where Damage Agent 1 ...
# 163  The location on the tree where Damage Agent 1 ...
# 165  A separate estimate of the diameter without th...
# 170  All juniper species, incense cedars, white fir...
# 174  Damage severity B is only coded when the Damag...
# 177  Damage severity B is only coded when the Damag...
# 180  A code indicating the sign or symptom recorded...
# 182  A code indicating the sign or symptom recorded...

# %%
usfs.table_schema('tree')["description"][133]
# Out:
# 'A code indicating the general quality of the tree. Prior to the merger of the Southern and Southeastern Research Stations (INVYR \uf0a31997), a growing-stock classification (code 2) was only assigned to species that were considered to have commercial value. Since the merger (INVYR >1997), code 2 has been applied to all tree species meeting the growing-stock form, grade, size and soundness requirements, regardless of commercial value. Only collected by certain FIA work units (SURVEY.RSCD = 33).'

# %% [markdown]
# Found that it corresponds to "tree_phase_2_plot_number"

# %%
for i in usfs.table_schema('tree')["name"]:
    print(i)
# Out:
# tree_sequence_number
# plot_sequence_number
# previous_tree_sequence_number
# tree_inventory_year
# tree_state_code
# tree_survey_unit_code
# tree_county_code
# tree_phase_2_plot_number
# subplot_number
# tree_record_number
# condition_class_number
# azimuth
# horizontal_distance
# previous_condition_number
# tree_status_code
# tree_status_code_name
# species_code
# species_common_name
# species_scientific_name
# species_group_code
# species_group_code_name
# current_diameter
# diameter_height_code
# diameter_height_code_name
# total_height
# height_method_code
# height_method_code_name
# actual_height
# tree_class_code
# tree_class_code_name
# compacted_crown_ratio
# crown_class_code
# crown_class_code_name
# tree_grade_code
# cause_death_agent_code
# cause_death_agent_code_name
# rotten_and_missing_cull
# damage_location_1
# damage_location_1_name
# damage_type_1
# damage_type_1_name
# damage_severity_1
# damage_severity_1_name
# damage_location_2
# damage_location_2_name
# damage_type_2
# damage_type_2_name
# damage_severity_2
# damage_severity_2_name
# decay_class_code
# decay_class_code_name
# tree_stocking
# woodland_tree_species_stem_count
# net_cubicfoot_volume
# gross_cubicfoot_volume
# net_cubicfoot_volume_sawlog_portion_sawtimber_tree
# gross_cubicfoot_volume_sawlog_portion_sawtimber_tree
# net_boardfoot_volume_sawlog_portion_sawtimber_tree
# gross_boardfoot_volume_sawlog_portion_sawtimber_tree
# sound_cubicfoot_volume
# net_annual_merchantable_cubicfoot_growth_growingstock_tree_timberland
# net_annual_merchantable_boardfoot_growth_sawtimber_tree_timberland
# net_annual_sound_cubicfoot_growth_live_tree_timberland
# merchantable_cubicfoot_volume_growingstock_tree_timberland_mortality_purposes
# merchantable_boardfoot_volume_sawtimber_tree_timberland_mortality_purposes
# sound_cubicfoot_volume_tree_timberland_mortality_purposes
# merchantable_cubicfoot_volume_growingstock_tree_timberland_removal_purposes
# merchantable_boardfoot_volume_sawtimber_tree_timberland_removal_purposes
# sound_cubicfoot_volume_live_tree_timberland_removal_purposes
# diameter_check_code
# diameter_check_code_name
# mortality_year
# salvable_dead_code
# salvable_dead_code_name
# uncompacted_live_crown_ratio
# crown_position_code
# crown_position_code_name
# crown_light_exposure_code
# crown_light_exposure_code_name
# crown_vigor_code_sapling
# crown_vigor_code_sapling_name
# crown_density_code
# crown_density_code_name
# crown_dieback_code
# crown_dieback_code_name
# foliage_transparency_code
# foliage_transparency_code_name
# tree_history_code
# current_diameter_calculated
# breast_height_age
# total_age
# dead_cull
# form_cull
# missing_top_cull_field_recorded
# boardfoot_cull
# cubicfoot_cull
# boardfootcull_soundness
# cubicfootcull_soundness
# sawlog_height
# bole_height
# form_class
# form_class_name
# current_height_calculated
# hardwood_clump_code
# calculated_site_index
# tree_created_by
# tree_created_date
# tree_created_in_instance
# tree_modified_by
# tree_modified_date
# tree_modified_in_instance
# mortality_code
# mortality_code_name
# height_to_diameter_measurement_point
# rough_cull
# mistletoe_class_code
# mistletoe_class_code_name
# rotten_missing_cull_field_recorded
# reconcile_code
# reconcile_code_name
# previous_diameter
# net_annual_merchantable_cubicfoot_growth_growingstock_tree_forest_land
# net_annual_merchantable_boardfoot_growth_sawtimber_tree_forest_land
# net_annual_sound_cubicfoot_growth_live_tree_forest_land
# merchantable_cubicfoot_volume_growingstock_tree_forest_land_mortality_purposes
# merchantable_boardfoot_volume_sawtimber_tree_forest_land_mortality_purposes
# sound_cubicfoot_volume_tree_forest_land_mortality_purposes
# merchantable_cubicfoot_volume_growingstock_tree_forest_land_removal_purposes
# merchantable_boardfoot_volume_sawtimber_tree_forest_land_removal_purposes
# sound_cubicfoot_volume_live_tree_forest_land_removal_purposes
# periodic_annual_growth_removal_mortality_flag
# tree_class_code_northeastern_research_station
# tree_class_code_northeastern_research_station_name
# tree_class_code_southern_research_station
# tree_class_code_southern_research_station_name
# tree_class_code_north_central_research_station
# tree_class_code_north_central_research_station_name
# tree_class_code_rocky_mountain_research_station
# tree_class_code_rocky_mountain_research_station_name
# standing_dead_code
# standing_dead_code_name
# previous_tree_status_code
# previous_tree_status_code_name
# previous_woodland_stem_count
# trees_per_acre_unadjusted
# mortality_trees_per_acre_per_year_unadjusted
# removal_trees_per_acre_per_year_unadjusted
# growth_trees_per_acre_unadjusted
# dry_biomass_in_the_merchantable_bole
# dry_biomass_top_limbs_tree
# dry_biomass_tree_stump_at_t_1
# aboveground_dry_biomass_saplings
# aboveground_dry_biomass_woodland_tree_species
# belowground_dry_biomass
# aboveground_carbon
# belowground_carbon
# tree_inventory_cycle_number
# tree_inventory_subcycle_number
# tree_bored_code_pacific_northwest_research_station
# tree_bored_code_pacific_northwest_research_station_name
# damage_location_1_pacific_northwest_research_station
# damage_location_1_pacific_northwest_research_station_name
# damage_location_2_pacific_northwest_research_station
# damage_location_2_pacific_northwest_research_station_name
# diameter_check_pacific_northwest_research_station
# diameter_check_pacific_northwest_research_station_name
# damage_agent_1_pacific_northwest_research_station
# damage_agent_2_pacific_northwest_research_station
# damage_agent_3_pacific_northwest_research_station
# leafy_mistletoe_class_code_pacific_northwest_research_station
# leafy_mistletoe_class_code_pacific_northwest_research_station_name
# damage_severity_1_pacific_northwest_research_station_years_2001_2004
# damage_severity_1_a_pacific_northwest_research_station
# damage_severity_1_b_pacific_northwest_research_station
# damage_severity_1_b_pacific_northwest_research_station_name
# damage_severity_2_pacific_northwest_research_station_years_2001_2004
# damage_severity_2_a_pacific_northwest_research_station_starting_2005
# damage_severity_2_b_pacific_northwest_research_station_starting_2005
# damage_severity_3_pacific_northwest_research_station_years_2001_2004
# unknown_damage_type_1_pacific_northwest_research_station
# unknown_damage_type_1_pacific_northwest_research_station_name
# unknown_damage_type_2_pacific_northwest_research_station
# unknown_damage_type_2_pacific_northwest_research_station_name
# previous_periodic_prism_point_tree_number_southern_research_station
# disease_southern_research_station
# disease_southern_research_station_name
# dieback_severity_southern_research_station
# dieback_severity_southern_research_station_name
# damage_agent_code_1
# damage_agent_code_1_name
# damage_agent_code_2
# damage_agent_code_2_name
# damage_agent_code_3
# damage_agent_code_3_name
# centroid_diameter
# calculated_centroid_diameter_height
# actual_centroid_diameter_height
# upper_stem_diameter
# upper_stem_diameter_height
# sound_cubicfoot_volume_sawlog_portion
# dry_biomass_sawlog_portion_sawtimber_tree
# damage_agent_code_1_southern_research_station
# damage_agent_code_2_southern_research_station
# damage_agent_code_3_southern_research_station
# aboveground_dry_biomass
# unique_tree
# actualht_calc
# actualht_calc_code
# cull_bf_rotten
# cull_bf_rotten_code
# cull_bf_rough
# cull_bf_rough_code
# prevdia_fld
# treecl_code_31_ncrs
# tree_grade_ncrs
# boughs_available_ncrs
# boughs_hrvst_ncrs
# treecl_code_31_ners
# agent_code_ners
# bfsnd_code_ners
# agechk_code_rmrs
# dia_1yrago_rmrs
# growbfscr_rmrs
# growcfsawlog_rmrs
# ht_1yrago_rmrs
# prev_actualht_rmrs
# prev_agechk_code_rmrs
# prev_bhage_rmrs
# prev_ht_rmrs
# prev_totage_rmrs
# prev_treecl_code_rmrs
# radage_code_rmrs
# radgrw_rmrs
# volbfscrgrs_rmrs
# volbfscrnet_rmrs
# volcfdeadgrs_rmrs
# volcfsawgrs_rmrs
# volcfsawnet_rmrs
# volcftotnet_rmrs
# volcfuppgrs_rmrs
# volcfuppnet_rmrs
# sapling_fusiform_srs
# epiphyte_pnwrs
# root_ht_pnwrs
# cavity_use_pnwrs
# core_length_pnwrs
# culturally_killed_pnwrs
# dia_est_pnwrs
# gst_pnwrs
# inc10yr_pnwrs
# inc5yrht_pnwrs
# inc5yr_pnwrs
# ring_count_inner_2inches_pnwrs
# ring_count_pnwrs
# snag_dis_code_pnwrs

# %%
query1 = f"""
    SELECT
        species_common_name,
        plot_state_code_name,
        plot_phase_2_plot_number,
        measurement_month,
        measurement_year,
        current_diameter as avg_dia,
        total_height as avg_heig,
        
    FROM
        `bigquery-public-data.usfs_fia.plot_tree`
    WHERE
        total_height > 0
        AND plot_state_code_name = 'California'
    GROUP BY
        species_common_name,
        plot_state_code_name,
        plot_phase_2_plot_number,
        measurement_month,
        measurement_year,
        current_diameter,
        total_height
    ;        """
response1 = usfs.query_to_pandas_safe(query1, max_gb_scanned=10)

# %%
response1['date'] = pd.to_datetime({'year':response1['measurement_year'],'month':response1['measurement_month'],'day': np.ones(response1["measurement_year"].size)})
# response1.head()
len(response1)
# Out:
# 335747

# %%
response1.plot_phase_2_plot_number.value_counts()
# Out:
# 28       547
# 18       444
# 55       432
# 24       430
# 25       419
#         ...
# 60142      1
# 97101      1
# 54833      1
# 51911      1
# 57192      1
# Name: plot_phase_2_plot_number, Length: 6083, dtype: int64

# %%
response1[response1.species_common_name == "Pacific madrone"]
# Out:
#        species_common_name plot_state_code_name  plot_phase_2_plot_number  \
# 46         Pacific madrone           California                       153
# 52         Pacific madrone           California                       184
# 84         Pacific madrone           California                       141
# 135        Pacific madrone           California                         3
# 249        Pacific madrone           California                       106
# ...                    ...                  ...                       ...
# 335527     Pacific madrone           California                     73243
# 335654     Pacific madrone           California                     97409
# 335670     Pacific madrone           California                     88939
# 335720     Pacific madrone           California                     82034
# 335729     Pacific madrone           California                     99719
#
#         measurement_month  measurement_year    avg_dia  avg_heig       date
# 46                     11              1991   2.800000        23 1991-11-01
# 52                      7              1991   6.200000        46 1991-07-01
# 84                      7              1991   9.700000        54 1991-07-01
# 135                    10              1991  14.100000        69 1991-10-01
# 249                     8              1991   2.000000        17 1991-08-01
# ...                   ...               ...        ...       ...        ...
# 335527                  5              2018   9.900000        39 2018-05-01
# 335654                 10              2018   9.300000        33 2018-10-01
# 335670                  7              2018   9.000000        66 2018-07-01
# 335720                  7              2018  15.200000        39 2018-07-01
# 335729                  4              2018  17.700001        84 2018-04-01
#
# [7031 rows x 8 columns]

# %%
# sugar_maple = response1.loc[(response1.plot_phase_2_plot_number == 33) & (response1.species_common_name =="Pacific madrone")]

pacific_madrone = response1.loc[(response1.plot_phase_2_plot_number == 28) & (response1.species_common_name =="Pacific madrone")]
pacific_madrone.plot_phase_2_plot_number.value_counts()
# Out:
# 28    6
# Name: plot_phase_2_plot_number, dtype: int64

# %%
# pacific_madrone.loc[(pacific_madrone.avg_heig>100) & (pacific_madrone.plot_phase_2_plot_number == 57038)]
taller = pacific_madrone.loc[(pacific_madrone.avg_heig>50)]

# %%
# sns.lmplot(data = taller, x = "date",y = "avg_heig")
plt.scatter(pacific_madrone["date"], pacific_madrone["avg_heig"])

# %%
#convert to something that sns.regplot can handle
date_maple = dates.datestr2num(sugar_maple.date.astype(str))
sugar_maple_dtn = sugar_maple.copy()
sugar_maple_dtn['dtn'] = date_maple

# %%
fig, ax = plt.subplots(figsize = (10,10))
sns.regplot(data = sugar_maple_dtn, x = "dtn",y = "avg_heig")
ax.xaxis.set_major_formatter(fake_dates)

# %%
query2 = """
SELECT
    species_common_name,
    measurement_year,
    plot_county_code,
FROM
    `bigquery-public-data.usfs_fia.plot_tree`
WHERE
    total_height > 0
    AND (plot_state_code_name = 'Oklahoma'
    OR plot_state_code_name = 'Texas'
    OR plot_state_code_name = 'Arkansas'
    OR plot_state_code_name = 'Lousiana'
    OR plot_state_code_name = 'Mississippi'
    OR plot_state_code_name = 'Alabama'
    OR plot_state_code_name = 'Tennesse'
    OR plot_state_code_name = 'Kentucky'
    OR plot_state_code_name = 'Georgia'
    OR plot_state_code_name = 'Florida'
    OR plot_state_code_name = 'Virginia'
    OR plot_state_code_name = 'North Carolina'
    OR plot_state_code_name = 'South Carolina'
    OR plot_state_code_name = 'Puerto Rico')


    
GROUP BY
    species_common_name,
    measurement_year,
    plot_county_code
;        """
response2 = usfs.query_to_pandas_safe(query2, max_gb_scanned=10)

# %%
response2.groupby('species_common_name').sum().reset_index();
response2_ordered = response2.species_common_name.value_counts()

# %%
top5 = response2_ordered.head(10)
top5 = top5.reset_index()

# %%
top5
# Out:
#                index  species_common_name
# 0          red maple                 5444
# 1           sweetgum                 5417
# 2      loblolly pine                 5378
# 3          water oak                 5091
# 4           blackgum                 4970
# 5   southern red oak                 4942
# 6          white oak                 4908
# 7       black cherry                 4868
# 8           post oak                 4812
# 9  flowering dogwood                 4601

# %%
plt.bar(top5["index"],top5["species_common_name"])
plt.xticks(rotation=90)
plt.yscale("log")
plt.title("Top 10 most common trees in Southern region", fontsize=14)
plt.ylabel("Count", fontsize=12)
plt.tight_layout()
plt.savefig("top10_trees_Southern.png", dpi=100)

# %%
query3 = """
SELECT
    tree_phase_2_plot_number,
    total_height as avg_heig,
    measurement_year,
    measurement_month,
    plot_county_code
FROM
    `bigquery-public-data.usfs_fia.plot_tree`
WHERE
    plot_state_code = 39
    AND total_height > 0

;        """
response3 = usfs.query_to_pandas_safe(query3, max_gb_scanned=10)
